# %% [markdown]
# # 데이터 분석 관련 포트폴리오
#
# 데이터분석을 시작한지 약 한 달이 되었다.
#
# 이제 어느 정도 기본적인 사용법에는 익숙해졌는데,
#
# 포트폴리오는 어떤 주제를 고르는 게 좋을까?
#
# 어떤 데이터를 쓰는 게 좋을까?
#
# 어디서 찾지? kaggle? 데이터댐?
#
# -> 사회적으로 이슈가 되는 데이터
#
# (분석.)
#
# EDA, 시각화, -> 결론
#
# 결과는
#
# "(1)사회적으로 이슈가 되고 있는 어떤 문제에 대하여, (2)분석 및 접근 가능한 데이터셋을 찾고,
#
# 내가 아는 모든 기법을 총동원하여, 문제해결에 실마리가 될 수 있는 (3)인사이트를 발견한다."

# %% [markdown]
# # 1. 문제제기
#
# # 2. 접근방법
#
# "코드", "시각화", "분석결과" 등
#
# # 3. 결론(인사이트)
#
#
# ![공공데이터포털 로고](https://www.data.go.kr/images/biz/common/logo/eg_logo.png)
#
# ![](https://i.ibb.co/Wpw7W0h/2023-07-05-123102.png)

# %%
import matplotlib.pyplot as plt

plt.plot([1,2,3,4,5], [2,4,6,1,8])

# %% [markdown]
# ![](https://i.ibb.co/1MJkq2S/2023-07-05-123923.png)
